#  [2.880e-04 1.840e-04 3.890e-04]
#  [6.790e-04 6.070e-04 6.930e-04]
#  [5.910e-04 1.599e-03 4.720e-04]
#  [1.013e-03 2.348e-03 5.300e-04]
#  [8.370e-04 3.729e-03 2.540e-04]
#  [4.680e-04 3.577e-03 2.150e-04]
#  [2.940e-04 3.138e-03 2.780e-04]
#  [3.050e-04 2.733e-03 2.650e-04]
#  [3.680e-04 3.758e-03 5.350e-04]
#  [3.560e-04 3.469e-03 6.190e-04]]

# %%
matriz = matriz.transpose()

# %%
print(matriz)
# Out:
# [[1.400e-05 2.700e-05 2.900e-05 1.320e-04 9.900e-05 2.140e-04 2.630e-04
#   4.300e-05 3.650e-04 2.880e-04 6.790e-04 5.910e-04 1.013e-03 8.370e-04
#   4.680e-04 2.940e-04 3.050e-04 3.680e-04 3.560e-04]
#  [2.200e-05 5.300e-05 7.100e-05 2.580e-04 6.500e-05 3.400e-04 1.590e-04
#   1.650e-04 5.330e-04 1.840e-04 6.070e-04 1.599e-03 2.348e-03 3.729e-03
#   3.577e-03 3.138e-03 2.733e-03 3.758e-03 3.469e-03]
#  [2.000e-05 3.700e-05 2.800e-05 1.180e-04 3.800e-05 1.980e-04 2.840e-04
#   5.500e-05 3.710e-04 3.890e-04 6.930e-04 4.720e-04 5.300e-04 2.540e-04
#   2.150e-04 2.780e-04 2.650e-04 5.350e-04 6.190e-04]]

# %%
Quick_Desv_bt = [1.400e-05, 2.700e-05, 2.900e-05, 1.320e-04, 9.900e-05, 2.140e-04, 2.630e-04,
  4.300e-05, 3.650e-04, 2.880e-04, 6.790e-04, 5.910e-04, 1.013e-03, 8.370e-04,
  4.680e-04, 2.940e-04, 3.050e-04, 3.680e-04, 3.560e-04]
Quick_Desv_mt = [2.200e-05, 5.300e-05, 7.100e-05, 2.580e-04, 6.500e-05, 3.400e-04, 1.590e-04,
  1.650e-04, 5.330e-04, 1.840e-04, 6.070e-04, 1.599e-03, 2.348e-03, 3.729e-03,
  3.577e-03, 3.138e-03, 2.733e-03, 3.758e-03, 3.469e-03]
Quick_Desv_wt = [2.000e-05, 3.700e-05, 2.800e-05, 1.180e-04, 3.800e-05, 1.980e-04, 2.840e-04,
  5.500e-05, 3.710e-04, 3.890e-04, 6.930e-04, 4.720e-04, 5.300e-04, 2.540e-04,
  2.150e-04, 2.780e-04, 2.650e-04, 5.350e-04, 6.190e-04]

# %%
Quick_Result_bt = [0.000114, 0.000284, 0.000402, 0.000510, 0.000728, 0.000789, 0.000700, 0.001037, 0.000860, 0.001234, 0.002091, 0.001611, 0.002325, 0.002850, 0.002782, 0.003299, 0.003607, 0.003980, 0.004676]
Quick_Result_mt = [0.000293, 0.000623, 0.000920, 0.001094, 0.001505, 0.001649, 0.002050, 0.002438, 0.002445, 0.002977, 0.005957, 0.006749, 0.008950, 0.009408, 0.010388, 0.011615, 0.012076, 0.012758, 0.013372]
Quick_Result_wt = [0.000102,0.000254,0.000381,0.000481,0.000669,0.000657,0.000687,0.001024,0.000789,0.001021,0.001660,0.001536,0.002073,0.002321,0.002663,0.003356,0.003712,0.004183,0.004996]

# %%
Heap_Result_bt = [0.000900, 0.001800, 0.002300, 0.003500, 0.002800, 0.004100, 0.003900, 0.004500, 0.004700, 0.004200, 0.008400, 0.012900, 0.018000, 0.022800, 0.027600, 0.030700, 0.038200, 0.041500, 0.045300]
Heap_Result_mt = [0.000800, 0.002100, 0.002700, 0.004200, 0.003200, 0.005300, 0.006000, 0.007700, 0.008700, 0.006400, 0.008300, 0.013300, 0.022000, 0.026600, 0.030600, 0.036300, 0.039200, 0.045200, 0.048800]
Heap_Result_wt = [0.000800, 0.001600, 0.001800, 0.002400, 0.001900, 0.002400, 0.002500, 0.003000, 0.003200, 0.003200, 0.007100, 0.012400, 0.014600, 0.018600, 0.022100, 0.025000, 0.028200, 0.031200, 0.034100]

# %%
mh = [[ 0.000539 ,  0.000600 ,  0.000400],
[ 0.000400 ,  0.000539 ,  0.000490],
[ 0.000781 ,  0.000640 ,  0.000872],
[ 0.001025 ,  0.000748 ,  0.001200],
[ 0.001600 ,  0.002040 ,  0.000831],
[ 0.002211 ,  0.001792 ,  0.000663],
[ 0.001640 ,  0.002191 ,  0.000806],
[ 0.001688 ,  0.002610 ,  0.000775],
[ 0.001418 ,  0.002326 ,  0.000600],
[ 0.001249 ,  0.002615 ,  0.000600],
[ 0.000490 ,  0.001792 ,  0.000943],
[ 0.000943 ,  0.002369 ,  0.001800],
[ 0.001183 ,  0.002646 ,  0.001356],
[ 0.000980 ,  0.002871 ,  0.001356],
[ 0.001855 ,  0.002871 ,  0.001044],
[ 0.001418 ,  0.002865 ,  0.000632],
[ 0.005056 ,  0.002713 ,  0.002135],
[ 0.001910 ,  0.002522 ,  0.000872],
[ 0.001616 ,  0.002315 ,  0.000700]]

# %%
mh = np.array(mh)
mh = mh.transpose()
print(mh)
# Out:
# [[0.000539 0.0004   0.000781 0.001025 0.0016   0.002211 0.00164  0.001688
#   0.001418 0.001249 0.00049  0.000943 0.001183 0.00098  0.001855 0.001418
#   0.005056 0.00191  0.001616]
#  [0.0006   0.000539 0.00064  0.000748 0.00204  0.001792 0.002191 0.00261
#   0.002326 0.002615 0.001792 0.002369 0.002646 0.002871 0.002871 0.002865
#   0.002713 0.002522 0.002315]
#  [0.0004   0.00049  0.000872 0.0012   0.000831 0.000663 0.000806 0.000775
#   0.0006   0.0006   0.000943 0.0018   0.001356 0.001356 0.001044 0.000632
#   0.002135 0.000872 0.0007  ]]

# %%
Heap_Desv_bt = [0.000539, 0.0004,   0.000781, 0.001025, 0.0016,   0.002211, 0.00164,  0.001688,
  0.001418, 0.001249, 0.00049,  0.000943, 0.001183, 0.00098,  0.001855, 0.001418,
  0.005056, 0.00191,  0.001616]
Heap_Desv_mt = [0.0006,   0.000539, 0.00064,  0.000748, 0.00204,  0.001792, 0.002191, 0.00261,
  0.002326, 0.002615, 0.001792, 0.002369, 0.002646, 0.002871, 0.002871, 0.002865,
  0.002713, 0.002522, 0.002315]
Heap_Desv_wt = [0.0004,   0.00049,  0.000872, 0.0012,   0.000831, 0.000663, 0.000806, 0.000775,
  0.0006,   0.0006,   0.000943, 0.0018,   0.001356, 0.001356, 0.001044, 0.000632,
  0.002135, 0.000872, 0.0007 ]

# %%
'''# le os valores do arquivo
f = open("/content/drive/MyDrive/NEGOCIO_DE_GRAFICO_DA_MATERIA_DO_PEDRONETTE/resultsInsertion.txt")
lines = [line.strip() for line in f.readlines()]
f.close()

# listas que devem guardar os valores
valbt = []
valmt = []
valwt = []
valbs = []
valms = []
valws = []
valbc = []
valmc = []
valwc = []

# separar elementos a cada pipe
for line in lines:
    x = line.split(",")
    valbt.append(float(x[0].split(":")[-1]))
    valmt.append(float(x[1].split(":")[-1]))
    valwt.append(float(x[2].split(":")[-1]))
    valbs.append(float(x[3].split(":")[-1]))
    valms.append(float(x[4].split(":")[-1]))
    valws.append(float(x[5].split(":")[-1]))
    valbc.append(float(x[6].split(":")[-1]))
    valmc.append(float(x[7].split(":")[-1]))
    valwc.append(float(x[8].split(":")[-1]))


print(valbt)
print(valmt)
print(valwt)
print(valbs)
print(valms)
print(valws)
print(valbc)
print(valmc)
print(valwc)

print(len(valwc))'''
# Out:
# '# le os valores do arquivo\nf = open("/content/drive/MyDrive/NEGOCIO_DE_GRAFICO_DA_MATERIA_DO_PEDRONETTE/resultsInsertion.txt")\nlines = [line.strip() for line in f.readlines()]\nf.close()\n\n# listas que devem guardar os valores\nvalbt = []\nvalmt = []\nvalwt = []\nvalbs = []\nvalms = []\nvalws = []\nvalbc = []\nvalmc = []\nvalwc = []\n\n# separar elementos a cada pipe\nfor line in lines:\n    x = line.split(",")\n    valbt.append(float(x[0].split(":")[-1]))\n    valmt.append(float(x[1].split(":")[-1]))\n    valwt.append(float(x[2].split(":")[-1]))\n    valbs.append(float(x[3].split(":")[-1]))\n    valms.append(float(x[4].split(":")[-1]))\n    valws.append(float(x[5].split(":")[-1]))\n    valbc.append(float(x[6].split(":")[-1]))\n    valmc.append(float(x[7].split(":")[-1]))\n    valwc.append(float(x[8].split(":")[-1]))\n\n\nprint(valbt)\nprint(valmt)\nprint(valwt)\nprint(valbs)\nprint(valms)\nprint(valws)\nprint(valbc)\nprint(valmc)\nprint(valwc)\n\nprint(len(valwc))'

# %%
def Grafico(valbt, valmt, valwt, vbt, vmt, vwt, titulo):
  valbt = np.array(valbt)
  valmt = np.array(valmt)
  valwt = np.array(valwt)
  vbt = np.array(vbt)
  vmt = np.array(vmt)
  vwt = np.array(vwt)

  print(valbt)
  print(type(valbt))
  print(valbt.size)
  EixoX = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000] 
  print(EixoX)
  EixoX = np.array(EixoX)
  print(EixoX.shape)
  valbt = np.array(valbt)
  print(valbt.shape)

  fig =  plt.figure()
  ax = fig.add_subplot(111)
  ax.set_xscale('log')
  plt.errorbar(EixoX, valbt, vbt)
  plt.xlabel("Tamanho da Entrada")
  plt.ylabel("Tempo de Execução")
  plt.title(titulo + " no Melhor Caso")
  fig.show()

  fig = 0.00

  fig =  plt.figure()
  ax = fig.add_subplot(111)
  ax.set_xscale('log')
  plt.errorbar(EixoX, valmt, vmt)
  plt.xlabel("Tamanho da Entrada")
  plt.ylabel("Tempo de Execução")
  plt.title(titulo + " no Caso Médio")
  fig.show()

  fi8g = 0.00

  fig =  plt.figure()
  ax = fig.add_subplot(111)
  ax.set_xscale('log')
  plt.errorbar(EixoX, valwt, vwt)
  plt.xlabel("Tamanho da Entrada")
  plt.ylabel("Tempo de Execução")
  plt.title(titulo + " no Pior Caso")
  fig.show()
  print('\n')

# %%
Grafico(Heap_Result_bt, Heap_Result_mt, Heap_Result_wt, Heap_Desv_bt, Heap_Desv_mt, Heap_Desv_wt, "HeapSort")
# Out:
# [0.0009 0.0018 0.0023 0.0035 0.0028 0.0041 0.0039 0.0045 0.0047 0.0042
#  0.0084 0.0129 0.018  0.0228 0.0276 0.0307 0.0382 0.0415 0.0453]
# <class 'numpy.ndarray'>
# 19
# [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000]
# (19,)
# (19,)

# %%
Grafico(Quick_Result_bt, Quick_Result_mt, Quick_Result_wt, Quick_Desv_bt, Quick_Desv_mt, Quick_Desv_wt, "QuickSort")
# Out:
# [0.000114 0.000284 0.000402 0.00051  0.000728 0.000789 0.0007   0.001037
#  0.00086  0.001234 0.002091 0.001611 0.002325 0.00285  0.002782 0.003299
#  0.003607 0.00398  0.004676]
# <class 'numpy.ndarray'>
# 19
# [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000]
# (19,)
# (19,)

# %%
Grafico(Insertion_Result_bt, Insertion_Result_mt, Insertion_Result_wt, Insertion_Desv_bt, Insertion_Desv_mt, Insertion_Desv_wt, "InsertionSort")
# Out:
# [1.10e-05 1.70e-05 1.30e-05 1.50e-05 1.50e-05 1.70e-05 2.30e-05 2.30e-05
#  2.60e-05 2.70e-05 5.30e-05 7.20e-05 9.80e-05 1.25e-04 1.42e-04 1.76e-04
#  1.93e-04 2.23e-04 2.44e-04]
# <class 'numpy.ndarray'>
# 19
# [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000]
# (19,)
# (19,)

# %%
Grafico(Selection_Result_bt, Selection_Result_mt, Selection_Result_wt, Selection_Desv_bt, Selection_Desv_mt, Selection_Desv_wt, "SelectionSort")
# Out:
# [1.776000e-03 4.957000e-03 8.207000e-03 1.476400e-02 2.257900e-02
#  3.256200e-02 4.373300e-02 5.705200e-02 7.159400e-02 8.769500e-02
#  3.381480e-01 7.464200e-01 1.339960e+00 2.066474e+00 3.069226e+00
#  4.008881e+00 4.893991e+00 6.233660e+00 7.687194e+00]
# <class 'numpy.ndarray'>
# 19
# [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000]
# (19,)
# (19,)

# %%
Grafico(Merge_Result_bt, Merge_Result_mt, Merge_Result_wt, Merge_Desv_bt, Merge_Desv_mt, Merge_Desv_wt, "MergeSort")
# Out:
# [0.000151 0.000387 0.00066  0.0009   0.001024 0.001257 0.001215 0.001047
#  0.001704 0.001658 0.002868 0.003546 0.004198 0.004594 0.005364 0.006606
#  0.007271 0.00829  0.009198]
# <class 'numpy.ndarray'>
# 19
# [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000]
# (19,)
# (19,)
